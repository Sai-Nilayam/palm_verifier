# %% [markdown]
# Here we are going to use out Data to Develop a Model that will take two images as input and tell us how similar they are.

# %%
# Makes Tensorflow showing less erros messages.
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Imports
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
import random
from tensorflow import keras
from tensorflow.keras import layers
from itertools import combinations

# %%
print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# ## Importing Images and Data set Preparation

# %%
# Lists all the file names from the Source folder
base_path = 'data/train/palm_images_resized/'

files = os.listdir(base_path)
files = [file for file in files if file[-1] != '~']

print(len(files))
# Out:
# 16

# %%
# Getting all the images in RGB formats and storing them all in a container array
classes = ['Vighnesh S.', 'Sai Nilayam Sahu', 'Vanshi', 'Yogesh', 'Norottam', 'Pratyush', 'Gopi', 'Abhay Kumar Singh']

X = []
y = []

for file in files:
    # Creating the File path (Image Path).
    file_path = base_path + file
    # Opening the Image using OpenCV
    inst_img = cv2.imread(file_path)
    # Converting the img to a Numpy Array
    inst_img_arr = np.array(inst_img)
    # Adding the Image Array to the Container Array. 
    X.append(inst_img_arr)
    
    # The other thing is to use grab the label from the Image name.
    inst_label = int(file[0])
    # Append the label to the 'y' Array.
    y.append(inst_label)
    
# Converting both X and y to Numpy Arrays for Efficient Computaion.
X = np.array(X)
y = np.array(y).reshape(len(X), -1)

print('Shape of X: ', X.shape)
print('Shape of y: ', y.shape)
# Out:
# Shape of X:  (16, 128, 64, 3)
# Shape of y:  (16, 1)

# %%
# Let's show one of the Image from our X Array.
index = 11

img = X[index]
# Converting BGR to RGB 
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

label = y[index][0]
class_ = classes[label]

print('Shape of the Image: ', img.shape)

plt.imshow(img)
plt.xlabel('{} - {}'.format(label, class_), size=12)
plt.show()
# Out:
# Shape of the Image:  (128, 64, 3)

# %% [markdown]
# ######

# %%
# Now the objective is to make the Training set for our Siamese Network.

# Making the big X_y Tensor.
X_y = []
for i in range(len(X)):
    inst_arr = []
    inst_X = X[i]
    inst_y = y[i]
    inst_arr.append(inst_X)
    inst_arr.append(inst_y)
    
    X_y.append(inst_arr)
    
print(len(X_y))
# Out:
# 16

# %%
# Now we will build X pairs and y label such that if the class of X pair is same the y label will be 1 and if the 
# class of X pairs is not same, y label is going to be 0.

# Creating index pairs to create combinations
all_combinations = combinations(range(16), 2)

all_combinations_list = [combination for combination in all_combinations]
    
# Appending some extra elements
extra_elements = [(i, i) for i in range(16)]
for ele in extra_elements:
    all_combinations_list.append(ele)

all_combinations = all_combinations_list

# Randomizing all_combinations with a Random seed 4.
random.Random(4).shuffle(all_combinations)
    
print(all_combinations, end='\n\n')
print(len(all_combinations))
# Out:
# [(9, 9), (1, 5), (0, 9), (3, 7), (11, 13), (7, 14), (0, 0), (4, 7), (3, 12), (6, 7), (1, 3), (6, 13), (7, 10), (12, 15), (6, 10), (2, 6), (5, 13), (1, 6), (1, 12), (4, 13), (10, 13), (0, 3), (3, 4), (5, 15), (0, 2), (1, 1), (4, 10), (3, 15), (4, 14), (7, 13), (4, 9), (1, 2), (5, 12), (0, 15), (10, 14), (0, 7), (5, 8), (3, 10), (7, 8), (5, 10), (6, 11), (10, 15), (7, 11), (6, 15), (7, 15), (14, 15), (8, 12), (4, 12), (6, 6), (13, 13), (0, 5), (0, 13), (8, 9), (0, 10), (9, 11), (3, 6), (2, 4), (2, 15), (11, 14), (13, 15), (8, 8), (2, 14), (4, 4), (6, 8), (0, 11), (7, 7), (9, 15), (8, 13), (2, 3), (1, 7), (4, 8), (4, 6), (2, 10), (4, 5), (3, 14), (12, 12), (5, 6), (12, 13), (5, 14), (8, 15), (0, 1), (2, 12), (5, 5), (8, 11), (12, 14), (15, 15), (7, 12), (11, 15), (2, 5), (4, 15), (3, 11), (7, 9), (3, 5), (14, 14), (0, 12), (3, 9), (8, 10), (6, 12), (3, 3), (10, 10), (1, 8), (1, 11), (2, 8), (11, 11), (11, 12), (9, 14), (6, 14), (10, 12), (0, 4), (1, 14), (2, 7), (0, 14), (10, 11), (1, 9), (9, 10), (2, 9), (3, 8), (5, 9), (5, 7), (1, 15), (0, 8), (8, 14), (9, 13), (2, 11), (13, 14), (5, 11), (3, 13), (0, 6), (1, 4), (1, 10), (2, 13), (2, 2), (9, 12), (1, 13), (6, 9), (4, 11)]
#
# 136

# %%
# Now we could do have 136 Training examples

X_1 = []
X_2 = []
y_similarity = []

for combination in all_combinations:
    x_1, x_2 = combination
    
    inst_img_1 = X[x_1]
    inst_img_2 = X[x_2]
    
    X_1.append(inst_img_1)
    X_2.append(inst_img_2)
    
    inst_y_1 = y[x_1][0]
    inst_y_2 = y[x_2][0]
    
    if inst_y_1 == inst_y_2:
        similarity = 1
    else:
        similarity = 0
    y_similarity.append(similarity)
    
X_1 = np.array(X_1)
X_2 = np.array(X_2)

y_similarity = np.array(y_similarity)
y_similarity = y_similarity.reshape(136, -1)
    
print(X_1.shape)
print(X_2.shape)
print(y_similarity.shape)
# Out:
# (136, 128, 64, 3)
# (136, 128, 64, 3)
# (136, 1)

# %%
# Testing our Training set.
index = 6

img_1 = X_1[index]
img_2 = X_2[index]
# Converting BGR to RGB 
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)

similarity = y_similarity[index][0]

print('Shape of the Image: ', img.shape)
plt.imshow(img_1)
plt.show()

print('Shape of the Image: ', img.shape)
plt.imshow(img_2)
plt.show()

print(similarity)
# Out:
# Shape of the Image:  (128, 64, 3)
# Shape of the Image:  (128, 64, 3)
# 1

# %% [markdown]
# ## Building a Siamese Network
# In this problem we are going to use a Siamese Network Architecture. This includes Convolutional Layers, Average Pooling Layers, Flatten Layer, Dense Layer, a Custom Layer.

# %%
# Building the Base Embedding Network

input_layer = tf.keras.layers.Input(shape=(128, 64, 3), name='input_layer')

x = tf.keras.layers.Conv2D(8, 3, strides=(1,1), padding='same', activation=tf.nn.sigmoid, name='conv_layer_1')(input_layer)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.AveragePooling2D(pool_size=(2, 2), name='average_pooling_layer_1')(x)

x = tf.keras.layers.Flatten(name='flatten_layer_1')(x)

output_layer = tf.keras.layers.Dense(512, activation=tf.nn.sigmoid, name='dense_layer_3')(x)

embedding_network = tf.keras.Model(inputs=input_layer, outputs=output_layer)

embedding_network.summary()
tf.keras.utils.plot_model(embedding_network)
# Out:
# Model: "model_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 128, 64, 3)]      0
# _________________________________________________________________
# conv_layer_1 (Conv2D)        (None, 128, 64, 8)        224
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 128, 64, 8)        32
# _________________________________________________________________
# average_pooling_layer_1 (Ave (None, 64, 32, 8)         0
# _________________________________________________________________
# flatten_layer_1 (Flatten)    (None, 16384)             0
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 512)               8389120
# =================================================================
# Total params: 8,389,376
# Trainable params: 8,389,360
# Non-trainable params: 16
# _________________________________________________________________

# %%
# Building the Siamese Network.

input_layer_1 = tf.keras.layers.Input(shape=(128, 64, 3), name='input_layer_for_img_1')
input_layer_2 = tf.keras.layers.Input(shape=(128, 64, 3), name='input_layer_for_img_2')

embedding_network_1 = embedding_network(input_layer_1)
embedding_network_2 = embedding_network(input_layer_2)

def euclidean_distance(tensor_list):
    x = tensor_list[0]
    y = tensor_list[1]
    sum_of_squres = tf.math.reduce_sum(tf.math.square(x - y), axis=1, keepdims=True)
    return sum_of_squres

merge_layer = tf.keras.layers.Lambda(euclidean_distance)([embedding_network_1, embedding_network_2])
similarity = tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)(merge_layer)

siamese_network = tf.keras.Model(inputs=[input_layer_1, input_layer_2], outputs=similarity)

siamese_network.summary()
tf.keras.utils.plot_model(siamese_network)
# Out:
# Model: "model_52"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer_for_img_1 (InputLay [(None, 128, 64, 3)] 0
# __________________________________________________________________________________________________
# input_layer_for_img_2 (InputLay [(None, 128, 64, 3)] 0
# __________________________________________________________________________________________________
# model_51 (Functional)           (None, 512)          8389376     input_layer_for_img_1[0][0]
#                                                                  input_layer_for_img_2[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           model_51[0][0]
#                                                                  model_51[1][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1)            2           lambda_22[0][0]
# ==================================================================================================
# Total params: 8,389,378
# Trainable params: 8,389,362
# Non-trainable params: 16
# __________________________________________________________________________________________________

# %%
# Definging the 'Cost Function', 'Optimizer' and 'Evaluation Metrics' for the Model.
siamese_network.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.007),
    metrics=['accuracy']
)

# %%
# Training the Model.
siamese_network.fit([X_1, X_2], y_similarity, batch_size=len(X_pair), epochs=1024, verbose=2)
# Out:
# Epoch 1/1024
# 1/1 - 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 2/1024
# 1/1 - 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 3/1024
# 1/1 - 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 4/1024
# 1/1 - 0s - loss: 0.0148 - accuracy: 1.0000
# Epoch 5/1024
# 1/1 - 0s - loss: 0.0148 - accuracy: 1.0000
# Epoch 6/1024
# 1/1 - 0s - loss: 0.0148 - accuracy: 1.0000
# Epoch 7/1024
# 1/1 - 0s - loss: 0.0147 - accuracy: 1.0000
# Epoch 8/1024
# 1/1 - 0s - loss: 0.0147 - accuracy: 1.0000
# Epoch 9/1024
# 1/1 - 0s - loss: 0.0147 - accuracy: 1.0000
# Epoch 10/1024
# 1/1 - 0s - loss: 0.0146 - accuracy: 1.0000
# Epoch 11/1024
# 1/1 - 0s - loss: 0.0146 - accuracy: 1.0000
# Epoch 12/1024
# 1/1 - 0s - loss: 0.0146 - accuracy: 1.0000
# Epoch 13/1024
# 1/1 - 0s - loss: 0.0145 - accuracy: 1.0000
# Epoch 14/1024
# 1/1 - 0s - loss: 0.0145 - accuracy: 1.0000
# Epoch 15/1024
# 1/1 - 0s - loss: 0.0145 - accuracy: 1.0000
# Epoch 16/1024
# 1/1 - 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 17/1024
# 1/1 - 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 18/1024
# 1/1 - 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 19/1024
# 1/1 - 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 20/1024
# 1/1 - 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 21/1024
# 1/1 - 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 22/1024
# 1/1 - 0s - loss: 0.0142 - accuracy: 1.0000
# Epoch 23/1024
# 1/1 - 0s - loss: 0.0142 - accuracy: 1.0000
# Epoch 24/1024
# 1/1 - 0s - loss: 0.0142 - accuracy: 1.0000
# Epoch 25/1024
# 1/1 - 1s - loss: 0.0141 - accuracy: 1.0000
# Epoch 26/1024
# 1/1 - 0s - loss: 0.0141 - accuracy: 1.0000
# Epoch 27/1024
# 1/1 - 1s - loss: 0.0141 - accuracy: 1.0000
# Epoch 28/1024
# 1/1 - 1s - loss: 0.0140 - accuracy: 1.0000
# Epoch 29/1024
# 1/1 - 0s - loss: 0.0140 - accuracy: 1.0000
# Epoch 30/1024
# 1/1 - 0s - loss: 0.0140 - accuracy: 1.0000
# Epoch 31/1024
# 1/1 - 0s - loss: 0.0140 - accuracy: 1.0000
# Epoch 32/1024
# 1/1 - 0s - loss: 0.0139 - accuracy: 1.0000
# Epoch 33/1024
# 1/1 - 0s - loss: 0.0139 - accuracy: 1.0000
# Epoch 34/1024
# 1/1 - 0s - loss: 0.0139 - accuracy: 1.0000
# Epoch 35/1024
# 1/1 - 0s - loss: 0.0138 - accuracy: 1.0000
# Epoch 36/1024
# 1/1 - 0s - loss: 0.0138 - accuracy: 1.0000
# Epoch 37/1024
# 1/1 - 0s - loss: 0.0138 - accuracy: 1.0000
# Epoch 38/1024
# 1/1 - 0s - loss: 0.0137 - accuracy: 1.0000
# Epoch 39/1024
# 1/1 - 0s - loss: 0.0137 - accuracy: 1.0000
# Epoch 40/1024
# 1/1 - 0s - loss: 0.0137 - accuracy: 1.0000
# Epoch 41/1024
# 1/1 - 0s - loss: 0.0136 - accuracy: 1.0000
# Epoch 42/1024
# 1/1 - 0s - loss: 0.0136 - accuracy: 1.0000
# Epoch 43/1024
# 1/1 - 0s - loss: 0.0136 - accuracy: 1.0000
# Epoch 44/1024
# 1/1 - 0s - loss: 0.0136 - accuracy: 1.0000
# Epoch 45/1024
# 1/1 - 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 46/1024
# 1/1 - 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 47/1024
# 1/1 - 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 48/1024
# 1/1 - 0s - loss: 0.0134 - accuracy: 1.0000
# Epoch 49/1024
# 1/1 - 0s - loss: 0.0134 - accuracy: 1.0000
# Epoch 50/1024
# 1/1 - 0s - loss: 0.0134 - accuracy: 1.0000
# Epoch 51/1024
# 1/1 - 0s - loss: 0.0133 - accuracy: 1.0000
# Epoch 52/1024
# 1/1 - 0s - loss: 0.0133 - accuracy: 1.0000
# Epoch 53/1024
# 1/1 - 0s - loss: 0.0133 - accuracy: 1.0000
# Epoch 54/1024
# 1/1 - 0s - loss: 0.0133 - accuracy: 1.0000
# Epoch 55/1024
# 1/1 - 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 56/1024
# 1/1 - 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 57/1024
# 1/1 - 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 58/1024
# 1/1 - 0s - loss: 0.0131 - accuracy: 1.0000
# Epoch 59/1024
# 1/1 - 0s - loss: 0.0131 - accuracy: 1.0000
# Epoch 60/1024
# 1/1 - 0s - loss: 0.0131 - accuracy: 1.0000
# Epoch 61/1024
# 1/1 - 0s - loss: 0.0131 - accuracy: 1.0000
# Epoch 62/1024
# 1/1 - 0s - loss: 0.0130 - accuracy: 1.0000
# Epoch 63/1024
# 1/1 - 0s - loss: 0.0130 - accuracy: 1.0000
# Epoch 64/1024
# 1/1 - 0s - loss: 0.0130 - accuracy: 1.0000
# Epoch 65/1024
# 1/1 - 0s - loss: 0.0129 - accuracy: 1.0000
# Epoch 66/1024
# 1/1 - 0s - loss: 0.0129 - accuracy: 1.0000
# Epoch 67/1024
# 1/1 - 0s - loss: 0.0129 - accuracy: 1.0000
# Epoch 68/1024
# 1/1 - 0s - loss: 0.0129 - accuracy: 1.0000
# Epoch 69/1024
# 1/1 - 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 70/1024
# 1/1 - 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 71/1024
# 1/1 - 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 72/1024
# 1/1 - 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 73/1024
# 1/1 - 0s - loss: 0.0127 - accuracy: 1.0000
# Epoch 74/1024
# 1/1 - 0s - loss: 0.0127 - accuracy: 1.0000
# Epoch 75/1024
# 1/1 - 0s - loss: 0.0127 - accuracy: 1.0000
# Epoch 76/1024
# 1/1 - 0s - loss: 0.0126 - accuracy: 1.0000
# Epoch 77/1024
# 1/1 - 0s - loss: 0.0126 - accuracy: 1.0000
# Epoch 78/1024
# 1/1 - 0s - loss: 0.0126 - accuracy: 1.0000
# Epoch 79/1024
# 1/1 - 0s - loss: 0.0126 - accuracy: 1.0000
# Epoch 80/1024
# 1/1 - 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 81/1024
# 1/1 - 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 82/1024
# 1/1 - 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 83/1024
# 1/1 - 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 84/1024
# 1/1 - 0s - loss: 0.0124 - accuracy: 1.0000
# Epoch 85/1024
# 1/1 - 0s - loss: 0.0124 - accuracy: 1.0000
# Epoch 86/1024
# 1/1 - 0s - loss: 0.0124 - accuracy: 1.0000
# Epoch 87/1024
# 1/1 - 0s - loss: 0.0124 - accuracy: 1.0000
# Epoch 88/1024
# 1/1 - 0s - loss: 0.0123 - accuracy: 1.0000
# Epoch 89/1024
# 1/1 - 0s - loss: 0.0123 - accuracy: 1.0000
# Epoch 90/1024
# 1/1 - 0s - loss: 0.0123 - accuracy: 1.0000
# Epoch 91/1024
# 1/1 - 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 92/1024
# 1/1 - 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 93/1024
# 1/1 - 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 94/1024
# 1/1 - 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 95/1024
# 1/1 - 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 96/1024
# 1/1 - 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 97/1024
# 1/1 - 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 98/1024
# 1/1 - 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 99/1024
# 1/1 - 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 100/1024
# 1/1 - 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 101/1024
# 1/1 - 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 102/1024
# 1/1 - 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 103/1024
# 1/1 - 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 104/1024
# 1/1 - 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 105/1024
# 1/1 - 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 106/1024
# 1/1 - 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 107/1024
# 1/1 - 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 108/1024
# 1/1 - 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 109/1024
# 1/1 - 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 110/1024
# 1/1 - 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 111/1024
# 1/1 - 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 112/1024
# 1/1 - 0s - loss: 0.0117 - accuracy: 1.0000
# Epoch 113/1024
# 1/1 - 0s - loss: 0.0117 - accuracy: 1.0000
# Epoch 114/1024
# 1/1 - 0s - loss: 0.0117 - accuracy: 1.0000
# Epoch 115/1024
# 1/1 - 0s - loss: 0.0117 - accuracy: 1.0000
# Epoch 116/1024
# 1/1 - 0s - loss: 0.0116 - accuracy: 1.0000
# Epoch 117/1024
# 1/1 - 0s - loss: 0.0116 - accuracy: 1.0000
# Epoch 118/1024
# 1/1 - 0s - loss: 0.0116 - accuracy: 1.0000
# Epoch 119/1024
# 1/1 - 0s - loss: 0.0116 - accuracy: 1.0000
# Epoch 120/1024
# 1/1 - 0s - loss: 0.0115 - accuracy: 1.0000
# Epoch 121/1024
# 1/1 - 0s - loss: 0.0115 - accuracy: 1.0000
# Epoch 122/1024
# 1/1 - 0s - loss: 0.0115 - accuracy: 1.0000
# Epoch 123/1024
# 1/1 - 0s - loss: 0.0115 - accuracy: 1.0000
# Epoch 124/1024
# 1/1 - 0s - loss: 0.0114 - accuracy: 1.0000
# Epoch 125/1024
# 1/1 - 0s - loss: 0.0114 - accuracy: 1.0000
# Epoch 126/1024
# 1/1 - 0s - loss: 0.0114 - accuracy: 1.0000
# Epoch 127/1024
# 1/1 - 0s - loss: 0.0114 - accuracy: 1.0000
# Epoch 128/1024
# 1/1 - 0s - loss: 0.0114 - accuracy: 1.0000
# Epoch 129/1024
# 1/1 - 0s - loss: 0.0113 - accuracy: 1.0000
# Epoch 130/1024
# 1/1 - 0s - loss: 0.0113 - accuracy: 1.0000
# Epoch 131/1024
# 1/1 - 0s - loss: 0.0113 - accuracy: 1.0000
# Epoch 132/1024
# 1/1 - 0s - loss: 0.0113 - accuracy: 1.0000
# Epoch 133/1024
# 1/1 - 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 134/1024
# 1/1 - 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 135/1024
# 1/1 - 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 136/1024
# 1/1 - 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 137/1024
# 1/1 - 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 138/1024
# 1/1 - 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 139/1024
# 1/1 - 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 140/1024
# 1/1 - 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 141/1024
# 1/1 - 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 142/1024
# 1/1 - 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 143/1024
# 1/1 - 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 144/1024
# 1/1 - 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 145/1024
# 1/1 - 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 146/1024
# 1/1 - 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 147/1024
# 1/1 - 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 148/1024
# 1/1 - 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 149/1024
# 1/1 - 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 150/1024
# 1/1 - 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 151/1024
# 1/1 - 0s - loss: 0.0108 - accuracy: 1.0000
# Epoch 152/1024
# 1/1 - 0s - loss: 0.0108 - accuracy: 1.0000
# Epoch 153/1024
# 1/1 - 0s - loss: 0.0108 - accuracy: 1.0000
# Epoch 154/1024
# 1/1 - 0s - loss: 0.0108 - accuracy: 1.0000
# Epoch 155/1024
# 1/1 - 0s - loss: 0.0108 - accuracy: 1.0000
# Epoch 156/1024
# 1/1 - 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 157/1024
# 1/1 - 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 158/1024
# 1/1 - 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 159/1024
# 1/1 - 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 160/1024
# 1/1 - 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 161/1024
# 1/1 - 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 162/1024
# 1/1 - 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 163/1024
# 1/1 - 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 164/1024
# 1/1 - 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 165/1024
# 1/1 - 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 166/1024
# 1/1 - 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 167/1024
# 1/1 - 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 168/1024
# 1/1 - 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 169/1024
# 1/1 - 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 170/1024
# 1/1 - 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 171/1024
# 1/1 - 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 172/1024
# 1/1 - 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 173/1024
# 1/1 - 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 174/1024
# 1/1 - 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 175/1024
# 1/1 - 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 176/1024
# 1/1 - 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 177/1024
# 1/1 - 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 178/1024
# 1/1 - 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 179/1024
# 1/1 - 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 180/1024
# 1/1 - 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 181/1024
# 1/1 - 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 182/1024
# 1/1 - 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 183/1024
# 1/1 - 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 184/1024
# 1/1 - 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 185/1024
# 1/1 - 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 186/1024
# 1/1 - 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 187/1024
# 1/1 - 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 188/1024
# 1/1 - 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 189/1024
# 1/1 - 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 190/1024
# 1/1 - 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 191/1024
# 1/1 - 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 192/1024
# 1/1 - 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 193/1024
# 1/1 - 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 194/1024
# 1/1 - 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 195/1024
# 1/1 - 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 196/1024
# 1/1 - 0s - loss: 0.0099 - accuracy: 1.0000
# Epoch 197/1024
# 1/1 - 0s - loss: 0.0099 - accuracy: 1.0000
# Epoch 198/1024
# 1/1 - 0s - loss: 0.0099 - accuracy: 1.0000
# Epoch 199/1024
# 1/1 - 0s - loss: 0.0099 - accuracy: 1.0000
# Epoch 200/1024
# 1/1 - 0s - loss: 0.0099 - accuracy: 1.0000
# Epoch 201/1024
# 1/1 - 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 202/1024
# 1/1 - 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 203/1024
# 1/1 - 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 204/1024
# 1/1 - 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 205/1024
# 1/1 - 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 206/1024
# 1/1 - 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 207/1024
# 1/1 - 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 208/1024
# 1/1 - 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 209/1024
# 1/1 - 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 210/1024
# 1/1 - 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 211/1024
# 1/1 - 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 212/1024
# 1/1 - 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 213/1024
# 1/1 - 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 214/1024
# 1/1 - 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 215/1024
# 1/1 - 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 216/1024
# 1/1 - 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 217/1024
# 1/1 - 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 218/1024
# 1/1 - 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 219/1024
# 1/1 - 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 220/1024
# 1/1 - 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 221/1024
# 1/1 - 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 222/1024
# 1/1 - 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 223/1024
# 1/1 - 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 224/1024
# 1/1 - 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 225/1024
# 1/1 - 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 226/1024
# 1/1 - 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 227/1024
# 1/1 - 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 228/1024
# 1/1 - 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 229/1024
# 1/1 - 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 230/1024
# 1/1 - 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 231/1024
# 1/1 - 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 232/1024
# 1/1 - 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 233/1024
# 1/1 - 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 234/1024
# 1/1 - 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 235/1024
# 1/1 - 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 236/1024
# 1/1 - 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 237/1024
# 1/1 - 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 238/1024
# 1/1 - 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 239/1024
# 1/1 - 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 240/1024
# 1/1 - 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 241/1024
# 1/1 - 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 242/1024
# 1/1 - 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 243/1024
# 1/1 - 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 244/1024
# 1/1 - 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 245/1024
# 1/1 - 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 246/1024
# 1/1 - 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 247/1024
# 1/1 - 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 248/1024
# 1/1 - 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 249/1024
# 1/1 - 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 250/1024
# 1/1 - 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 251/1024
# 1/1 - 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 252/1024
# 1/1 - 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 253/1024
# 1/1 - 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 254/1024
# 1/1 - 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 255/1024
# 1/1 - 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 256/1024
# 1/1 - 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 257/1024
# 1/1 - 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 258/1024
# 1/1 - 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 259/1024
# 1/1 - 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 260/1024
# 1/1 - 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 261/1024
# 1/1 - 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 262/1024
# 1/1 - 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 263/1024
# 1/1 - 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 264/1024
# 1/1 - 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 265/1024
# 1/1 - 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 266/1024
# 1/1 - 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 267/1024
# 1/1 - 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 268/1024
# 1/1 - 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 269/1024
# 1/1 - 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 270/1024
# 1/1 - 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 271/1024
# 1/1 - 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 272/1024
# 1/1 - 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 273/1024
# 1/1 - 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 274/1024
# 1/1 - 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 275/1024
# 1/1 - 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 276/1024
# 1/1 - 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 277/1024
# 1/1 - 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 278/1024
# 1/1 - 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 279/1024
# 1/1 - 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 280/1024
# 1/1 - 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 281/1024
# 1/1 - 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 282/1024
# 1/1 - 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 283/1024
# 1/1 - 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 284/1024
# 1/1 - 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 285/1024
# 1/1 - 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 286/1024
# 1/1 - 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 287/1024
# 1/1 - 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 288/1024
# 1/1 - 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 289/1024
# 1/1 - 1s - loss: 0.0084 - accuracy: 1.0000
# Epoch 290/1024
# 1/1 - 1s - loss: 0.0084 - accuracy: 1.0000
# Epoch 291/1024
# 1/1 - 1s - loss: 0.0084 - accuracy: 1.0000
# Epoch 292/1024
# 1/1 - 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 293/1024
# 1/1 - 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 294/1024
# 1/1 - 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 295/1024
# 1/1 - 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 296/1024
# 1/1 - 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 297/1024
# 1/1 - 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 298/1024
# 1/1 - 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 299/1024
# 1/1 - 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 300/1024
# 1/1 - 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 301/1024
# 1/1 - 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 302/1024
# 1/1 - 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 303/1024
# 1/1 - 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 304/1024
# 1/1 - 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 305/1024
# 1/1 - 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 306/1024
# 1/1 - 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 307/1024
# 1/1 - 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 308/1024
# 1/1 - 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 309/1024
# 1/1 - 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 310/1024
# 1/1 - 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 311/1024
# 1/1 - 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 312/1024
# 1/1 - 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 313/1024
# 1/1 - 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 314/1024
# 1/1 - 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 315/1024
# 1/1 - 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 316/1024
# 1/1 - 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 317/1024
# 1/1 - 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 318/1024
# 1/1 - 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 319/1024
# 1/1 - 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 320/1024
# 1/1 - 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 321/1024
# 1/1 - 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 322/1024
# 1/1 - 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 323/1024
# 1/1 - 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 324/1024
# 1/1 - 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 325/1024
# 1/1 - 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 326/1024
# 1/1 - 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 327/1024
# 1/1 - 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 328/1024
# 1/1 - 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 329/1024
# 1/1 - 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 330/1024
# 1/1 - 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 331/1024
# 1/1 - 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 332/1024
# 1/1 - 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 333/1024
# 1/1 - 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 334/1024
# 1/1 - 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 335/1024
# 1/1 - 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 336/1024
# 1/1 - 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 337/1024
# 1/1 - 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 338/1024
# 1/1 - 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 339/1024
# 1/1 - 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 340/1024
# 1/1 - 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 341/1024
# 1/1 - 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 342/1024
# 1/1 - 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 343/1024
# 1/1 - 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 344/1024
# 1/1 - 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 345/1024
# 1/1 - 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 346/1024
# 1/1 - 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 347/1024
# 1/1 - 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 348/1024
# 1/1 - 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 349/1024
# 1/1 - 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 350/1024
# 1/1 - 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 351/1024
# 1/1 - 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 352/1024
# 1/1 - 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 353/1024
# 1/1 - 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 354/1024
# 1/1 - 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 355/1024
# 1/1 - 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 356/1024
# 1/1 - 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 357/1024
# 1/1 - 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 358/1024
# 1/1 - 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 359/1024
# 1/1 - 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 360/1024
# 1/1 - 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 361/1024
# 1/1 - 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 362/1024
# 1/1 - 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 363/1024
# 1/1 - 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 364/1024
# 1/1 - 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 365/1024
# 1/1 - 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 366/1024
# 1/1 - 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 367/1024
# 1/1 - 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 368/1024
# 1/1 - 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 369/1024
# 1/1 - 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 370/1024
# 1/1 - 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 371/1024
# 1/1 - 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 372/1024
# 1/1 - 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 373/1024
# 1/1 - 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 374/1024
# 1/1 - 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 375/1024
# 1/1 - 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 376/1024
# 1/1 - 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 377/1024
# 1/1 - 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 378/1024
# 1/1 - 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 379/1024
# 1/1 - 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 380/1024
# 1/1 - 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 381/1024
# 1/1 - 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 382/1024
# 1/1 - 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 383/1024
# 1/1 - 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 384/1024
# 1/1 - 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 385/1024
# 1/1 - 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 386/1024
# 1/1 - 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 387/1024
# 1/1 - 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 388/1024
# 1/1 - 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 389/1024
# 1/1 - 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 390/1024
# 1/1 - 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 391/1024
# 1/1 - 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 392/1024
# 1/1 - 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 393/1024
# 1/1 - 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 394/1024
# 1/1 - 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 395/1024
# 1/1 - 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 396/1024
# 1/1 - 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 397/1024
# 1/1 - 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 398/1024
# 1/1 - 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 399/1024
# 1/1 - 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 400/1024
# 1/1 - 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 401/1024
# 1/1 - 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 402/1024
# 1/1 - 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 403/1024
# 1/1 - 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 404/1024
# 1/1 - 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 405/1024
# 1/1 - 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 406/1024
# 1/1 - 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 407/1024
# 1/1 - 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 408/1024
# 1/1 - 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 409/1024
# 1/1 - 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 410/1024
# 1/1 - 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 411/1024
# 1/1 - 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 412/1024
# 1/1 - 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 413/1024
# 1/1 - 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 414/1024
# 1/1 - 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 415/1024
# 1/1 - 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 416/1024
# 1/1 - 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 417/1024
# 1/1 - 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 418/1024
# 1/1 - 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 419/1024
# 1/1 - 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 420/1024
# 1/1 - 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 421/1024
# 1/1 - 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 422/1024
# 1/1 - 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 423/1024
# 1/1 - 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 424/1024
# 1/1 - 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 425/1024
# 1/1 - 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 426/1024
# 1/1 - 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 427/1024
# 1/1 - 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 428/1024
# 1/1 - 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 429/1024
# 1/1 - 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 430/1024
# 1/1 - 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 431/1024
# 1/1 - 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 432/1024
# 1/1 - 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 433/1024
# 1/1 - 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 434/1024
# 1/1 - 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 435/1024
# 1/1 - 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 436/1024
# 1/1 - 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 437/1024
# 1/1 - 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 438/1024
# 1/1 - 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 439/1024
# 1/1 - 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 440/1024
# 1/1 - 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 441/1024
# 1/1 - 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 442/1024
# 1/1 - 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 443/1024
# 1/1 - 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 444/1024
# 1/1 - 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 445/1024
# 1/1 - 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 446/1024
# 1/1 - 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 447/1024
# 1/1 - 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 448/1024
# 1/1 - 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 449/1024
# 1/1 - 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 450/1024
# 1/1 - 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 451/1024
# 1/1 - 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 452/1024
# 1/1 - 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 453/1024
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 454/1024
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 455/1024
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 456/1024
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 457/1024
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 458/1024
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 459/1024
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 460/1024
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 461/1024
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 462/1024
# 1/1 - 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 463/1024
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 464/1024
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 465/1024
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 466/1024
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 467/1024
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 468/1024
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 469/1024
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 470/1024
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 471/1024
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 472/1024
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 473/1024
# 1/1 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 474/1024
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 475/1024
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 476/1024
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 477/1024
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 478/1024
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 479/1024
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 480/1024
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 481/1024
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 482/1024
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 483/1024
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 484/1024
# 1/1 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 485/1024
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 486/1024
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 487/1024
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 488/1024
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 489/1024
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 490/1024
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 491/1024
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 492/1024
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 493/1024
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 494/1024
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 495/1024
# 1/1 - 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 496/1024
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 497/1024
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 498/1024
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 499/1024
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 500/1024
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 501/1024
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 502/1024
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 503/1024
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 504/1024
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 505/1024
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 506/1024
# 1/1 - 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 507/1024
# 1/1 - 1s - loss: 0.0059 - accuracy: 1.0000
# Epoch 508/1024
# 1/1 - 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 509/1024
# 1/1 - 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 510/1024
# 1/1 - 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 511/1024
# 1/1 - 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 512/1024
# 1/1 - 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 513/1024
# 1/1 - 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 514/1024
# 1/1 - 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 515/1024
# 1/1 - 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 516/1024
# 1/1 - 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 517/1024
# 1/1 - 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 518/1024
# 1/1 - 1s - loss: 0.0059 - accuracy: 1.0000
# Epoch 519/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 520/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 521/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 522/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 523/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 524/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 525/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 526/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 527/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 528/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 529/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 530/1024
# 1/1 - 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 531/1024
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 532/1024
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 533/1024
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 534/1024
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 535/1024
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 536/1024
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 537/1024
# 1/1 - 1s - loss: 0.0057 - accuracy: 1.0000
# Epoch 538/1024
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 539/1024
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 540/1024
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 541/1024
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 542/1024
# 1/1 - 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 543/1024
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 544/1024
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 545/1024
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 546/1024
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 547/1024
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 548/1024
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 549/1024
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 550/1024
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 551/1024
# 1/1 - 1s - loss: 0.0056 - accuracy: 1.0000
# Epoch 552/1024
# 1/1 - 1s - loss: 0.0056 - accuracy: 1.0000
# Epoch 553/1024
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 554/1024
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 555/1024
# 1/1 - 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 556/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 557/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 558/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 559/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 560/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 561/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 562/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 563/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 564/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 565/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 566/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 567/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 568/1024
# 1/1 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 569/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 570/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 571/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 572/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 573/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 574/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 575/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 576/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 577/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 578/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 579/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 580/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 581/1024
# 1/1 - 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 582/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 583/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 584/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 585/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 586/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 587/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 588/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 589/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 590/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 591/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 592/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 593/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 594/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 595/1024
# 1/1 - 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 596/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 597/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 598/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 599/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 600/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 601/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 602/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 603/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 604/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 605/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 606/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 607/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 608/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 609/1024
# 1/1 - 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 610/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 611/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 612/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 613/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 614/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 615/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 616/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 617/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 618/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 619/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 620/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 621/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 622/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 623/1024
# 1/1 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 624/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 625/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 626/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 627/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 628/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 629/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 630/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 631/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 632/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 633/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 634/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 635/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 636/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 637/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 638/1024
# 1/1 - 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 639/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 640/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 641/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 642/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 643/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 644/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 645/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 646/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 647/1024
# 1/1 - 1s - loss: 0.0049 - accuracy: 1.0000
# Epoch 648/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 649/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 650/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 651/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 652/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 653/1024
# 1/1 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 654/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 655/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 656/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 657/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 658/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 659/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 660/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 661/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 662/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 663/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 664/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 665/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 666/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 667/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 668/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 669/1024
# 1/1 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 670/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 671/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 672/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 673/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 674/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 675/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 676/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 677/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 678/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 679/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 680/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 681/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 682/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 683/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 684/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 685/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 686/1024
# 1/1 - 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 687/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 688/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 689/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 690/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 691/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 692/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 693/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 694/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 695/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 696/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 697/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 698/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 699/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 700/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 701/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 702/1024
# 1/1 - 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 703/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 704/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 705/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 706/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 707/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 708/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 709/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 710/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 711/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 712/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 713/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 714/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 715/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 716/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 717/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 718/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 719/1024
# 1/1 - 1s - loss: 0.0045 - accuracy: 1.0000
# Epoch 720/1024
# 1/1 - 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 721/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 722/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 723/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 724/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 725/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 726/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 727/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 728/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 729/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 730/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 731/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 732/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 733/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 734/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 735/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 736/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 737/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 738/1024
# 1/1 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 739/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 740/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 741/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 742/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 743/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 744/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 745/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 746/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 747/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 748/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 749/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 750/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 751/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 752/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 753/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 754/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 755/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 756/1024
# 1/1 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 757/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 758/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 759/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 760/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 761/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 762/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 763/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 764/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 765/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 766/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 767/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 768/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 769/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 770/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 771/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 772/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 773/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 774/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 775/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 776/1024
# 1/1 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 777/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 778/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 779/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 780/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 781/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 782/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 783/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 784/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 785/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 786/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 787/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 788/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 789/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 790/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 791/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 792/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 793/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 794/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 795/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 796/1024
# 1/1 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 797/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 798/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 799/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 800/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 801/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 802/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 803/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 804/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 805/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 806/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 807/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 808/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 809/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 810/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 811/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 812/1024
# 1/1 - 1s - loss: 0.0040 - accuracy: 1.0000
# Epoch 813/1024
# 1/1 - 1s - loss: 0.0040 - accuracy: 1.0000
# Epoch 814/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 815/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 816/1024
# 1/1 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 817/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 818/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 819/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 820/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 821/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 822/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 823/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 824/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 825/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 826/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 827/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 828/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 829/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 830/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 831/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 832/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 833/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 834/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 835/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 836/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 837/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 838/1024
# 1/1 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 839/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 840/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 841/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 842/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 843/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 844/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 845/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 846/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 847/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 848/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 849/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 850/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 851/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 852/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 853/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 854/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 855/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 856/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 857/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 858/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 859/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 860/1024
# 1/1 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 861/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 862/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 863/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 864/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 865/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 866/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 867/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 868/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 869/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 870/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 871/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 872/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 873/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 874/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 875/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 876/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 877/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 878/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 879/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 880/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 881/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 882/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 883/1024
# 1/1 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 884/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 885/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 886/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 887/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 888/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 889/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 890/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 891/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 892/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 893/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 894/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 895/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 896/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 897/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 898/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 899/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 900/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 901/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 902/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 903/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 904/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 905/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 906/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 907/1024
# 1/1 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 908/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 909/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 910/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 911/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 912/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 913/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 914/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 915/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 916/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 917/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 918/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 919/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 920/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 921/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 922/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 923/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 924/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 925/1024
# 1/1 - 1s - loss: 0.0035 - accuracy: 1.0000
# Epoch 926/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 927/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 928/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 929/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 930/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 931/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 932/1024
# 1/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 933/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 934/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 935/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 936/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 937/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 938/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 939/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 940/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 941/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 942/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 943/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 944/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 945/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 946/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 947/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 948/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 949/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 950/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 951/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 952/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 953/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 954/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 955/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 956/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 957/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 958/1024
# 1/1 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 959/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 960/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 961/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 962/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 963/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 964/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 965/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 966/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 967/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 968/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 969/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 970/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 971/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 972/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 973/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 974/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 975/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 976/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 977/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 978/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 979/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 980/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 981/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 982/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 983/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 984/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 985/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 986/1024
# 1/1 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 987/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 988/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 989/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 990/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 991/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 992/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 993/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 994/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 995/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 996/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 997/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 998/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 999/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1000/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1001/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1002/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1003/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1004/1024
# 1/1 - 1s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1005/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1006/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1007/1024
# 1/1 - 1s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1008/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1009/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1010/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1011/1024
# 1/1 - 1s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1012/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1013/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1014/1024
# 1/1 - 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 1015/1024
# 1/1 - 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 1016/1024
# 1/1 - 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 1017/1024
# 1/1 - 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 1018/1024
# 1/1 - 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 1019/1024
# 1/1 - 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 1020/1024
# 1/1 - 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 1021/1024
# 1/1 - 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 1022/1024
# 1/1 - 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 1023/1024
# 1/1 - 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 1024/1024
# 1/1 - 0s - loss: 0.0031 - accuracy: 1.0000

# %%
# Saving the Model. Once we get a good model then only we save the model using the following codes. 
# siamese_network.save('models/model_1/')
# Out:
# INFO:tensorflow:Assets written to: models/model_1/assets

# %% [markdown]
# ## Model Building Completed
# From the Evaluation of the model using just he Train set itself, our model got an accuracy of 100%. This is awesome. Due to lack of Data we don't have a Dev set right now.

# %% [markdown]
# ## Model Testing

# %%
# Importing the Model.
model_test = tf.keras.models.load_model('models/model_1/')

model_test.summary()
# Out:
# Model: "model_52"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer_for_img_1 (InputLay [(None, 128, 64, 3)] 0
# __________________________________________________________________________________________________
# input_layer_for_img_2 (InputLay [(None, 128, 64, 3)] 0
# __________________________________________________________________________________________________
# model_51 (Functional)           (None, 512)          8389376     input_layer_for_img_1[0][0]
#                                                                  input_layer_for_img_2[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           model_51[0][0]
#                                                                  model_51[1][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1)            2           lambda_22[0][0]
# ==================================================================================================
# Total params: 8,389,378
# Trainable params: 8,389,362
# Non-trainable params: 16
# __________________________________________________________________________________________________

# %%
# Creating testing Data pairs
img_1 = cv2.imread('data/test/palm_images_resized/6_1.jpg')
img_1 = np.array(img_1)

img_2 = cv2.imread('data/test/palm_images_resized/6_2.jpg')
img_2 = np.array(img_2)

X_1_test = [img_1]
X_2_test = [img_2]

X_1_test = np.array(X_1_test)
X_2_test = np.array(X_2_test)

print(X_1_test.shape)
print(X_2_test.shape)
# Out:
# (1, 128, 64, 3)
# (1, 128, 64, 3)

# %%
# Testing our Training set.

# Converting BGR to RGB 
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)

print('Shape of the Image: ', img.shape)
plt.imshow(img_1)
plt.show()

print('Shape of the Image: ', img.shape)
plt.imshow(img_2)
plt.show()
# Out:
# Shape of the Image:  (128, 64, 3)
# Shape of the Image:  (128, 64, 3)

# %%
prediction = model_test.predict([X_1_test, X_2_test])[0][0]
print('Similarity between two Images:', prediction)

if prediction > 0.8:
    print('1')
    print('Two Palms are of Same.')
else:
    print('0')
    print('Tow Palms are not Same.')
# Out:
# Similarity between two Images: 0.97301465
# 1
# Two Palms are of Same.
