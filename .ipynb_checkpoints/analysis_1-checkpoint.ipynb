# %%
import pandas as pd

# %%
df = pd.read_csv('data/indices.csv')
display(df)
# Out:
#    Index               Name  Room No.
# 0      1         VIGNESH S.       101
# 1      2   SAI NILAYAM SAHU       101
# 2      3              VASHI       303
# 3      4             YOGESH       303
# 4      5           NAROTTAM       205
# 5      6           PRATYUSH       205
# 6      7               GOPI       403
# 7      8  ABHAY KUMAR SINGH       301
